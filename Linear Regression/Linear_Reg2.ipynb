# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load Dataset
df=pd.read_csv('/kaggle/input/linear-reg-demo/Linear_Reg2.csv')
df
# Out:
#    age  premium
# 0    1    18000
# 1    2    32000
# 2    3    40000
# 3    4    47000
# 4    5    55000
# 5    6    60000
# 6    7    75000
# 7    8    80000
# 8    9    95000
# 9   10    99000

# %%
df.head()
# Out:
#    age  premium
# 0    1    18000
# 1    2    32000
# 2    3    40000
# 3    4    47000
# 4    5    55000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
sns.scatterplot(x='age',y='premium',data=df)
# Out:
# <Axes: xlabel='age', ylabel='premium'>

# %%
y=df[['age']]
x=df[['premium']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#    premium
# 7    80000
# 3    47000
# 8    95000
# 1    32000
# 9    99000
# 2    40000
# 0    18000

# %%
x_test
# Out:
#    premium
# 4    55000
# 5    60000
# 6    75000

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test
# Out:
#    age
# 4    5
# 5    6
# 6    7

# %%
y_pred
# Out:
# array([[4.86828154],
#        [5.43021024],
#        [7.11599634]])
